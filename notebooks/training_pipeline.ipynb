# %% [markdown]
# # CICIDS Training Pipeline
#
# This notebook mirrors the scripted training flow while still letting you poke at intermediate artifacts.
# - ✅ Reads a YAML config so you can reuse the same hyper-parameters everywhere.
# - ✅ Calls the production `src/train_supervised.py` logic (no code drift).
# - ✅ Returns metadata and metrics that you can log/share.
#
# > Tip: run `mlflow ui --backend-store-uri mlruns` from the project root to browse experiments after this notebook finishes.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path("..").resolve()
SRC_PATH = PROJECT_ROOT / "src"
if str(SRC_PATH) not in sys.path:
    sys.path.append(str(SRC_PATH))

from train_supervised import run_training

CONFIG_PATH = PROJECT_ROOT / "configs" / "train_default.yaml"
results = run_training(str(CONFIG_PATH))
results

# %%
import json

REGISTRY_PATH = PROJECT_ROOT / "src" / "models" / "model_registry.json"
with open(REGISTRY_PATH, "r", encoding="utf-8") as f:
    registry = json.load(f)

registry[-3:] if registry else registry
